# %% [markdown]
# ### Semi-Synthetic Experiments Plots

# %%
import pandas as pd 
import pickle
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from create_plots import *
import sys
import os

# the following code lets you import a python file from a different directory
path_to_file = os.path.join(os.path.dirname('plot_util.py'), '..')

sys.path.append(path_to_file)

from plot_util import *

# %%
file_name_addon = 'sklearn_nopenalty'
filename = f'column_plot_data_{file_name_addon}.csv'

# %%
# take the pre-calculated data and convert it to a csv format that we use to create plots
create_csv(f'../estimate_grid_outputs/estimate_grid_save_{file_name_addon}.p', f'column_plot_data_{file_name_addon}.csv', gamma_min=1, gamma_max=2)

# %%
data_order = [{"oracle": "A-Sis", "P1M": ("Echo", "flan", "Radiology", "flan"), "P2M": ("Echo", "flan", "Radiology", "olmo")},
              {"oracle": "Heart", "P1M": ("Echo", "flan", "Nursing", "flan"), "P2M": ("Echo", "flan", "Nursing", "olmo")}]
              # {"oracle": "A-Sis", "P1M": ("Radiology", "flan", "Nursing", "flan"), "P2M": ("Radiology", "flan", "Nursing", "olmo")}]
create_plots(filename, data_order, rows=1, cols=2, width=8, height=3)

# %%
data_order = [{"oracle": "A-Fib", "P1M": ("ECG", "flan", "Echo", "flan"), "P2M": ("ECG", "flan", "Echo", "olmo")},
              {"oracle": "A-Fib", "P1M": ("ECG", "flan", "Nursing", "flan"), "P2M": ("ECG", "flan", "Nursing", "olmo")},
              {"oracle": "A-Fib", "P1M": ("Echo", "flan", "Nursing", "flan"), "P2M": ("Echo", "flan", "Nursing", "olmo")},
              {"oracle": "Heart", "P1M": ("Echo", "flan", "Nursing", "flan"), "P2M": ("Echo", "flan", "Nursing", "olmo")},
              {"oracle": "A-Sis", "P1M": ("Echo", "flan", "Nursing", "flan"), "P2M": ("Echo", "flan", "Nursing", "olmo")},
              {"oracle": "A-Sis", "P1M": ("Echo", "flan", "Radiology", "flan"), "P2M": ("Echo", "flan", "Radiology", "olmo")},
              {"oracle": "A-Sis", "P1M": ("Radiology", "flan", "Nursing", "flan"), "P2M": ("Radiology", "flan", "Nursing", "olmo")},
              {"oracle": "Hypertension", "P1M": ("Echo", "flan", "Nursing", "flan"), "P2M": ("Echo", "flan", "Nursing", "olmo")}]
create_plots(filename, data_order, rows=4, cols=2, height=12)
